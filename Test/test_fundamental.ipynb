# %%
import sys
Path = '/Users/nick0o0o0/Library/Mobile Documents/com~apple~CloudDocs/gxyfile/Trading/Stocks_selection'
sys.path.insert(0, Path)

import pandas as pd
import yfinance as yf



ticker = 'HROW'
Ticker = yf.Ticker(ticker)

# %%
#!/usr/bin/env python
try:
    # For Python 3.0 and later
    from urllib.request import urlopen, Request
except ImportError:
    # Fall back to Python 2's urllib2
    from urllib2 import urlopen, Request

import certifi
import json

def get_jsonparsed_data(url):
    headers = {'User-Agent': 'Mozilla/5.0'}
    request = Request(url, headers=headers)
    response = urlopen(request, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

API = "XoCFDNkNI1VORV7iopIe7vwsf5yxWlxe"
url = f"https://financialmodelingprep.com/api/v3/income-statement/AAPL?period=annual&apikey={API}"

def get_jsonparsed_data(url):
    headers = {'User-Agent': 'Mozilla/5.0'}
    request = Request(url, headers=headers)
    response = urlopen(request, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

data = get_jsonparsed_data(url)
# Out:
# /var/folders/km/vjt389x91b93k1_jy0g3jscc0000gn/T/ipykernel_24062/1809161132.py:25: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(request, cafile=certifi.where())

# %%
data
# Out:
# [{'date': '2023-09-30',
#   'symbol': 'AAPL',
#   'reportedCurrency': 'USD',
#   'cik': '0000320193',
#   'fillingDate': '2023-11-03',
#   'acceptedDate': '2023-11-02 18:08:27',
#   'calendarYear': '2023',
#   'period': 'FY',
#   'revenue': 383285000000,
#   'costOfRevenue': 214137000000,
#   'grossProfit': 169148000000,
#   'grossProfitRatio': 0.4413112958,
#   'researchAndDevelopmentExpenses': 29915000000,
#   'generalAndAdministrativeExpenses': 0,
#   'sellingAndMarketingExpenses': 0,
#   'sellingGeneralAndAdministrativeExpenses': 24932000000,
#   'otherExpenses': 382000000,
#   'operatingExpenses': 55229000000,
#   'costAndExpenses': 269366000000,
#   'interestIncome': 3750000000,
#   'interestExpense': 3933000000,
#   'depreciationAndAmortization': 11519000000,
#   'ebitda': 125820000000,
#   'ebitdaratio': 0.3282674772,
#   'operatingIncome': 114301000000,
#   'operatingIncomeRatio': 0.2982141227,
#   'totalOtherIncomeExpensesNet': 565000000,
# ...

# %%
Ticker.quarterly_cashflow
# Out:
#                                                 2024-06-30  2024-03-31  \
# Free Cash Flow                                  -3153000.0  -4738000.0
# Repayment Of Debt                                      0.0         0.0
# Issuance Of Debt                                       0.0         0.0
# Issuance Of Capital Stock                              NaN         NaN
# Capital Expenditure                              -407000.0   -110000.0
# Interest Paid Supplemental Data                  4976000.0   5340000.0
# Income Tax Paid Supplemental Data                      0.0         0.0
# End Cash Position                               70968000.0  68538000.0
# Beginning Cash Position                         68538000.0  74085000.0
# Changes In Cash                                  2430000.0  -5547000.0
# Financing Cash Flow                                73000.0   -809000.0
# Cash Flow From Continuing Financing Activities     73000.0   -809000.0
# ...

# %%
data
# Out:
# {'Error Message': 'Exclusive Endpoint : This endpoint is not available under your current subscription agreement, please visit our subscription page to upgrade your plan or contact us at https://site.financialmodelingprep.com/developer/docs/pricing'}

# %%
HROW = yf.Ticker(ticker)

# %%
HROW.quarterly_income_stmt
# Out:
#                                                     2024-06-30  2024-03-31  \
# Tax Effect Of Unusual Items                          -403830.0     -1372.8
# Tax Rate For Calcs                                        0.21      0.0011
# Normalized EBITDA                                    4776000.0  -3722000.0
# Total Unusual Items                                 -1923000.0  -1248000.0
# Total Unusual Items Excluding Goodwill              -1923000.0  -1248000.0
# Net Income From Continuing Operation Net Minori...  -6473000.0 -13565000.0
# Reconciled Depreciation                              3200000.0   3180000.0
# Reconciled Cost Of Revenue                          12539000.0  10553000.0
# EBITDA                                               2853000.0  -4970000.0
# EBIT                                                 -347000.0  -8150000.0
# Net Interest Income                                 -5471000.0  -5415000.0
# ...

# %%
# import requests
# API = 'L9YXXXRSY2IFLQQ3'
# url = 'https://www.alphavantage.co/query?function=EARNINGS&symbol=HROW&apikey=' + API
# r = requests.get(url)
# data = r.json()

# earnings_df = pd.DataFrame(data)
# earnings_df
# Out:
#    fiscalDateEnding reportedDate reportedEPS estimatedEPS surprise  \
# 0        2024-06-30   2024-08-07       -0.18         -0.2     0.02
# 1        2024-03-31   2024-05-13       -0.38         -0.2    -0.18
# 2        2023-12-31   2024-03-19       -0.25        -0.04    -0.21
# 3        2023-09-30   2023-11-13       -0.13         0.04    -0.17
# 4        2023-06-30   2023-08-09       -0.14        -0.04     -0.1
# ..              ...          ...         ...          ...      ...
# 63       2008-09-30   2008-12-03     -2.1082         None     None
# 64       2008-06-30   2008-09-03     -3.4315         None     None
# 65       2008-03-31   2008-05-28     -0.7947         None     None
# 66       2007-12-31   2008-02-27     -6.8715         None     None
# 67       2007-09-30   2007-09-30    -11.4761         None     None
#
#    surprisePercentage   reportTime
# 0                  10  post-market
# 1                 -90  post-market
# 2                -525  post-market
# ...

# %%
data.keys()
# Out:
# dict_keys(['symbol', 'annualEarnings', 'quarterlyEarnings'])

# %%
data['annualEarnings']
# Out:
# [{'fiscalDateEnding': '2024-09-30', 'reportedEPS': '-0.56'},
#  {'fiscalDateEnding': '2023-12-31', 'reportedEPS': '-0.74'},
#  {'fiscalDateEnding': '2022-12-31', 'reportedEPS': '-0.4'},
#  {'fiscalDateEnding': '2021-12-31', 'reportedEPS': '-0.66'},
#  {'fiscalDateEnding': '2020-12-31', 'reportedEPS': '-0.43'},
#  {'fiscalDateEnding': '2019-12-31', 'reportedEPS': '0.15'},
#  {'fiscalDateEnding': '2018-12-31', 'reportedEPS': '0.59'},
#  {'fiscalDateEnding': '2017-12-31', 'reportedEPS': '-0.93'},
#  {'fiscalDateEnding': '2016-12-31', 'reportedEPS': '-1.36'},
#  {'fiscalDateEnding': '2015-12-31', 'reportedEPS': '-1.61'},
#  {'fiscalDateEnding': '2014-12-31', 'reportedEPS': '-1.1429'},
#  {'fiscalDateEnding': '2013-12-31', 'reportedEPS': '-0.8795'},
#  {'fiscalDateEnding': '2012-12-31', 'reportedEPS': '-2.2093'},
#  {'fiscalDateEnding': '2011-12-31', 'reportedEPS': '-2.6481'},
#  {'fiscalDateEnding': '2010-12-31', 'reportedEPS': '-6.5048'},
# ...

# %%
earnings_df.dtypes
# Out:
# fiscalDateEnding      object
# reportedDate          object
# reportedEPS           object
# estimatedEPS          object
# surprise              object
# surprisePercentage    object
# reportTime            object
# dtype: object

# %%
# url = 'https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol=HROW&apikey=' + API
# r = requests.get(url)
# data = r.json()

# print(data.keys())
# Out:
# dict_keys(['symbol', 'annualReports', 'quarterlyReports'])

# %%
income_df = pd.DataFrame(data['quarterlyReports'])
income_df.columns
# Out:
# Index(['fiscalDateEnding', 'reportedCurrency', 'grossProfit', 'totalRevenue',
#        'costOfRevenue', 'costofGoodsAndServicesSold', 'operatingIncome',
#        'sellingGeneralAndAdministrative', 'researchAndDevelopment',
#        'operatingExpenses', 'investmentIncomeNet', 'netInterestIncome',
#        'interestIncome', 'interestExpense', 'nonInterestIncome',
#        'otherNonOperatingIncome', 'depreciation',
#        'depreciationAndAmortization', 'incomeBeforeTax', 'incomeTaxExpense',
#        'interestAndDebtExpense', 'netIncomeFromContinuingOperations',
#        'comprehensiveIncomeNetOfTax', 'ebit', 'ebitda', 'netIncome'],
#       dtype='object')

# %%
income_df.head()
# Out:
#   fiscalDateEnding reportedCurrency grossProfit totalRevenue costOfRevenue  \
# 0       2024-06-30              USD    36400000     48939000      46905000
# 1       2024-03-31              USD    24034000     34587000      39978000
# 2       2023-12-31              USD    25053000     31231000      38329000
# 3       2023-09-30              USD    24198000     28516000      33684000
# 4       2023-06-30              USD    23470000     27766000      32800000
#
#   costofGoodsAndServicesSold operatingIncome sellingGeneralAndAdministrative  \
# 0                   12539000         1530000                        31817000
# 1                   10553000        -6928000                        28813000
# 2                   11302000        -4875000                        26212000
# 3                   10067000         1744000                        21033000
# 4                   10000000         2352000                        19957000
#
# ...

# %%
ff.get_quarterly_fundamental(ticker)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 ff.get_quarterly_fundamental(ticker)
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/gxyfile/Trading/Stocks_selection/Nick_Module/fundamental_function.py:42, in get_quarterly_fundamental(Ticker)
#      38 """
#      39 return the quarterly fundamental of the stock by
#      40 """
#      41 df = pd.DataFrame()
# ---> 42 income_sts_df = get_income_statement(Ticker)
#      43 EPS_df = get_EPS(Ticker)
#      44 merge_df = pd.merge(income_sts_df, EPS_df, on='fiscalDateEnding')
#
# File ~/Library/Mobile Documents/com~apple~CloudDocs/gxyfile/Trading/Stocks_selection/Nick_Module/fundamental_function.py:34, in get_income_statement(Ticker, time)
#      32     income_df = pd.DataFrame(data['annualReports'])
#      33 elif time == 'Q':
# ---> 34     income_df = pd.DataFrame(data['quarterlyReports'])
# ...
